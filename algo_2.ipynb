# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/algo-I253F/blob/main/algo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
print(a)
a=a==8
print(a)
# Out:
# 5
# False

# %%
int(5/2)
# Out:
# 2

# %%
n=int(input("Masukkan sembarang nilai ?"))
if n%2==0:
  print(f"{n} adalah bilangan Genap")
else:
  print(f"{n} adalah bilangan Ganjil")
# Out:
# Masukkan sembarang nilai ?11
# 11 bilangan Ganjil

# %%
a=int(input("Masukkan alas segi tiga ?"))
t=int(input("Masukkan tinggi segi tiga ?"))

l=1/2*a*t
print(f"Luas segitiga dengan alas={a} dan tinggi={t} adalah {l}")
# Out:
# Masukkan alas segi tiga ?20
# Masukkan tinggi segi tiga ?12
# Luas segitiga dengan alas=20 dan tinggi=12 adalah 120.0
