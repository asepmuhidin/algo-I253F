# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/algo-I253F/blob/main/algo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=12.5
#Bagaimana cara mengetahui tipe data dari sebuah variabel
type(a)
# Out:
# float

# %%
a,b=10,23
a +=b # a=a+b ==> a=10+23=33
b +=a # b=b+a ==> b=23+33

print(f"Nilai a={a}")
print(f"Nilai b={b}")

#nilai a=33, b=56
# Out:
# Nilai a=33
# Nilai b=56

# %%
a=10
a=90
a=0
print(a)
# Out:
# 0

# %%
kopi="Kopi panas"
teh="Teh anget"

c=teh
teh=kopi
kopi=c

print(f"Nilai gelas kopi ={kopi}")
print(f"Nilai gelas teh ={teh}")
# Out:
# Nilai gelas kopi =Teh anget
# Nilai gelas teh =Kopi panas

# %%
r=10 #1. Menentukan nilai jari-jari (r) lingkaran.
pi=3.14 #2. Menentukan nilai phi.
luas=r*r*pi #3. Menghitung luas lingkaran dengan cara mengkalikan nilai jari-jari (r) dengan (r) lalu dikalikan dengan nilai phi.
print(f"Luas lingkaran dengan jari-jar {r} adalah {luas}")#4. Maka luas lingkaran ditemukan.
#5. Selesai.
# Out:
# Luas lingkaran dengan jari-jar 10 adalah 314.0

# %%
print("Luas lingkara", luas, r)
# Out:
# Luas lingkara 314.0 10
