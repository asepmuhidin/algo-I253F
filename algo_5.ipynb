# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/algo-I253F/blob/main/algo_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3*'aku'
# Out:
# 'akuakuaku'

# %%
'-'*20
# Out:
# '--------------------'

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4771/927109222.py in <cell line: 0>()
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
data=''
if data is None:
  print('ss')

# %%
daftar_siswa=['ade','amelia','dini','jenet','fina']

if 'dini' in daftar_siswa:
  print('ada')
else:
  print('tidak ada')
# Out:
# ada

# %%
if 'ilham' not in daftar_siswa:
  print('tidak ada')
else:
  print('ada')
# Out:
# tidak ada

# %%
kalimat='malam ini seharusnya libur, karena kelas online jadi tidak libur'
if 'karena' in kalimat:
  print('ada')
else:
  print('tidak ada')
# Out:
# ada

# %%
x=10
x=x+5
x
# Out:
# 15

# %%
x=20
x +=10
x
# Out:
# 30

# %%
x=14
x <<= 2
x
# Out:
# 56

# %%
z=10
z <<=2
z
# Out:
# 40
